# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df=pd.read_csv("CAR DETAILS FROM CAR DEKHO copy.csv")
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 0     Petrol  Individual       Manual   First Owner
# 1     Petrol  Individual       Manual   First Owner
# 2     Diesel  Individual       Manual   First Owner
# 3     Petrol  Individual       Manual   First Owner
# 4     Diesel  Individual       Manual  Second Owner
# ...      ...         ...          ...           ...
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner
#
# [4340 rows x 8 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 0     Petrol  Individual       Manual   First Owner
# 1     Petrol  Individual       Manual   First Owner
# 2     Diesel  Individual       Manual   First Owner
# 3     Petrol  Individual       Manual   First Owner
# 4     Diesel  Individual       Manual  Second Owner
# ...      ...         ...          ...           ...
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner
#
# [4340 rows x 8 columns]>

# %%
plt.figure(figsize=(8,6))
sns.countplot(x="seller_type",data=df,palette="viridis")
plt.title("selling type count plot")
plt.xlabel("seller type")
plt.ylabel("count")
plt.show()
# Out:
# /var/folders/wp/hft_4m3d2nx9j8fsn18yl0f40000gn/T/ipykernel_6989/4243668064.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="seller_type",data=df,palette="viridis")

# %%
plt.figure(figsize=(8,6))
sns.histplot(df["year"].dropna(),bins=30,kde=True,color="blue")
plt.title("hisplot for year")
plt.xlabel("year")
plt.ylabel("count")
plt.show()

# %%
cars=df["owner"].value_counts()
plt.figure(figsize=(8,6))
plt.pie(cars,labels=["first owner","second owner","third owner","fourth & above owner","test drive car"],
        autopct="%1.1f%%",colors=["lightcoral","lightgreen","red","blue","royalblue"],
        startangle=180,explode=(0.05,0.05,0.05,0.05,0.05))
plt.title("car details")
plt.show()

# %%
cars=df["owner"].value_counts()
cars
# Out:
# owner
# First Owner             2832
# Second Owner            1106
# Third Owner              304
# Fourth & Above Owner      81
# Test Drive Car            17
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x="year",y="km_driven",data=df,hue="owner",style="seller_type",palette="rainbow")
plt.title("scatter plot of year vs km_driven with owner and seller_type")
plt.xlabel("year")
plt.ylabel("km_driven")
plt.legend(title="km_driven")
plt.show()

# %%
num=df[["year","selling_price","km_driven"]].corr()
num
# Out:
#                    year  selling_price  km_driven
# year           1.000000       0.413922  -0.419688
# selling_price  0.413922       1.000000  -0.192289
# km_driven     -0.419688      -0.192289   1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8))

sns.scatterplot(
    x="score_1",
    y="score_2",
    data=df,
    hue="stage",
    style="decided_by_penalties",
    palette="rainbow"
)

plt.title("Scatter Plot of Score 1 vs Score 2")
plt.xlabel("Score 1")
plt.ylabel("Score 2")
plt.legend(title="Stage")

plt.show()

# %%
sns.kdeplot(data=df["year"].dropna(),color="skyblue",shade="True")
plt.title("year distribution(kernel density estimate)")
plt.xlabel("year")
plt.ylabel("density")
plt.show()
# Out:
# /var/folders/wp/hft_4m3d2nx9j8fsn18yl0f40000gn/T/ipykernel_6989/3323305534.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=df["year"].dropna(),color="skyblue",shade="True")

# %%
g=sns.FacetGrid(df,col="seller_type",row="owner",margin_titles=True)
g.map(sns.histplot,"year",bins=20,color="teal")
g.fig.suptitle("age distriabition by class and survival",y=1.03)
plt.show()

# %%
sns.pairplot(df[["year","selling_price","km_driven","transmission"]],hue="transmission",palette="husl",plot_kws={"alpha":0.6},diag_kind="kde")
plt.suptitle("pair plot of titanic variables",y=1.02)
plt.show()
